# %%
import pandas as pd
df=pd.DataFrame({'Number of Males':[10,15,25,14],'Number of Females':[20,25,15,10]},index=['Italian','Indian','Mexican','Chinese'])
percent_df=df.apply(lambda x:(x*100)/sum(x),axis=1)
percent_df.plot.barh(stacked=True,title='Male Vs Female',)
# Out:
# <AxesSubplot:title={'center':'Male Vs Female'}>
